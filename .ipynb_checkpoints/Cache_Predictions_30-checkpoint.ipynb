# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.pages.prediction import load_data, load_weights, create_ip
from src.pages.predict import predict
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in to_bytes(self, obj, context)
#     288             # Hash the input
# --> 289             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     290
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in _to_bytes(self, obj, context)
#     544
# --> 545             if self._file_should_be_hashed(obj.__code__.co_filename):
#     546                 context = _get_context(obj)
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in _file_should_be_hashed(self, filename)
#     323         return file_util.file_is_in_folder_glob(
# --> 324             filepath, self._get_main_script_directory()
#     325         ) or file_util.file_in_pythonpath(filepath)
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in _get_main_script_directory()
#     626         # script path in ScriptRunner.
# --> 627         main_path = __main__.__file__
#     628         return os.path.dirname(main_path)
#
# AttributeError: module '__main__' has no attribute '__file__'
#
# During handling of the above exception, another exception occurred:
#
# InternalHashError                         Traceback (most recent call last)
# <ipython-input-4-b63561e267db> in <module>
#       4 import seaborn as sns
#       5
# ----> 6 from src.pages.prediction import load_data, load_weights, create_ip
#       7 from src.pages.predict import predict
#
# D:\Prabodh\Programs\Team-Streamlit_Pred\src\pages\prediction.py in <module>
#       7 from plotly.subplots import make_subplots
#       8 import plotly.graph_objects as go
# ----> 9 from src.pages.predict import predict
#      10 from typing import List, Optional
#      11 import random
#
# D:\Prabodh\Programs\Team-Streamlit_Pred\src\pages\predict.py in <module>
#       4 import streamlit as st
#       5
# ----> 6 from src.pages.predictor.tempgeolstm_predictor import tempGeoLSTMPredictor
#       7 from src.pages.predictor.tempgeolgbm_predictor import tempGeoLGBMPredictor
#       8
#
# D:\Prabodh\Programs\Team-Streamlit_Pred\src\pages\predictor\tempgeolstm_predictor.py in <module>
#      22 import streamlit as st
#      23
# ---> 24 import src.pages.predictor.base as base
#      25 from src.pages.predictor.base import BasePredictor
#      26
#
# D:\Prabodh\Programs\Team-Streamlit_Pred\src\pages\predictor\base.py in <module>
#      47                    'Population']
#      48
# ---> 49 @st.cache(persist=True, allow_output_mutation=True, show_spinner=False)
#      50 def load_oxford_data():
#      51     data = pd.read_csv(OXFORD_FILEPATH, parse_dates=['Date'], encoding="ISO-8859-1", dtype={"RegionName": str, "RegionCode": str}, error_bad_lines=False)
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\caching.py in <lambda>(f)
#     458             hash_funcs=hash_funcs,
#     459             max_entries=max_entries,
# --> 460             ttl=ttl,
#     461         )
#     462
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\caching.py in cache(func, persist, allow_output_mutation, show_spinner, suppress_st_warning, hash_funcs, max_entries, ttl)
#     490         hash_funcs=hash_funcs,
#     491         hash_reason=HashReason.CACHING_FUNC_BODY,
# --> 492         hash_source=func,
#     493     )
#     494
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in update_hash(val, hasher, hash_reason, hash_source, context, hash_funcs)
#      88
#      89     ch = _CodeHasher(hash_funcs)
# ---> 90     ch.update(hasher, val, context)
#      91
#      92
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in update(self, hasher, obj, context)
#     312     def update(self, hasher, obj, context=None):
#     313         """Update the provided hasher with the hash of an object."""
# --> 314         b = self.to_bytes(obj, context)
#     315         hasher.update(b)
#     316
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in to_bytes(self, obj, context)
#     287         try:
#     288             # Hash the input
# --> 289             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     290
#     291             # Hmmm... It's possible that the size calculation is wrong. When we
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in _to_bytes(self, obj, context)
#     362             h = hashlib.new("md5")
#     363             for item in obj:
# --> 364                 self.update(h, item, context)
#     365             return h.digest()
#     366
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in update(self, hasher, obj, context)
#     312     def update(self, hasher, obj, context=None):
#     313         """Update the provided hasher with the hash of an object."""
# --> 314         b = self.to_bytes(obj, context)
#     315         hasher.update(b)
#     316
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in to_bytes(self, obj, context)
#     301
#     302         except BaseException as e:
# --> 303             raise InternalHashError(e, obj)
#     304
#     305         finally:
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in to_bytes(self, obj, context)
#     287         try:
#     288             # Hash the input
# --> 289             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     290
#     291             # Hmmm... It's possible that the size calculation is wrong. When we
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in _to_bytes(self, obj, context)
#     543             h = hashlib.new("md5")
#     544
# --> 545             if self._file_should_be_hashed(obj.__code__.co_filename):
#     546                 context = _get_context(obj)
#     547                 if obj.__defaults__:
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in _file_should_be_hashed(self, filename)
#     322             return False
#     323         return file_util.file_is_in_folder_glob(
# --> 324             filepath, self._get_main_script_directory()
#     325         ) or file_util.file_in_pythonpath(filepath)
#     326
#
# c:\users\prabo\appdata\local\programs\python\python37\lib\site-packages\streamlit\hashing.py in _get_main_script_directory()
#     625         # This works because we set __main__.__file__ to the report
#     626         # script path in ScriptRunner.
# --> 627         main_path = __main__.__file__
#     628         return os.path.dirname(main_path)
#     629
#
# InternalHashError: module '__main__' has no attribute '__file__'
#
# While caching the body of `load_oxford_data()`, Streamlit encountered an
# object of type `builtins.function`, which it does not know how to hash.
#
# **In this specific case, it's very likely you found a Streamlit bug so please
# [file a bug report here.]
# (https://github.com/streamlit/streamlit/issues/new/choose)**
#
# In the meantime, you can try bypassing this error by registering a custom
# hash function via the `hash_funcs` keyword in @st.cache(). For example:
#
# ```
# @st.cache(hash_funcs={builtins.function: my_hash_func})
# def my_func(...):
#     ...
# ```
#
# If you don't know where the object of type `builtins.function` is coming
# from, try looking at the hash chain below for an object that you do recognize,
# then pass that to `hash_funcs` instead:
#
# ```
# Object of type builtins.function: <function load_oxford_data at 0x000001EE451D1C18>
# Object of type builtins.tuple: ('src.pages.predictor.base', 'load_oxford_data', <function load_oxford_data at 0x000001EE451D1C18>)
# ```
#
# Please see the `hash_funcs` [documentation]
# (https://streamlit.io/docs/caching.html)
# for more details.

# %%
def load_data():
	data = pd.read_csv("src/data/casesanddeaths.csv", parse_dates=["Date"])
	return data

def load_weights():
	data = pd.re

# %%
data = load_data()
countries = list(data.sort_values(by="ConfirmedCases", ascending=False)["CountryName"].unique())
n_days = 30
weights = load_weights()
c1 = weights[weights["CountryName"]==selected_country]["C1_School closing"].reset_index(drop=True)[0]
c2 = weights[weights["CountryName"]==selected_country]["C2_Workplace closing"].reset_index(drop=True)[0]
c3 = weights[weights["CountryName"]==selected_country]["C4_Restrictions on gatherings"].reset_index(drop=True)[0]
c4 = weights[weights["CountryName"]==selected_country]["C5_Close public transport"].reset_index(drop=True)[0]
c5 = weights[weights["CountryName"]==selected_country]["C6_Stay at home requirements"].reset_index(drop=True)[0]
c6 = weights[weights["CountryName"]==selected_country]["C7_Restrictions on internal movement"].reset_index(drop=True)[0]
c7 = weights[weights["CountryName"]==selected_country]["C8_International travel controls"].reset_index(drop=True)[0]
c8 = weights[weights["CountryName"]==selected_country]["H1_Public information campaigns"].reset_index(drop=True)[0]
h1 = weights[weights["CountryName"]==selected_country]["H1_Public information campaigns"].reset_index(drop=True)[0]
h2 = weights[weights["CountryName"]==selected_country]["H2_Testing policy"].reset_index(drop=True)[0]
h3 = weights[weights["CountryName"]==selected_country]["H3_Contact tracing"].reset_index(drop=True)[0]
h6 = weights[weights["CountryName"]==selected_country]["H6_Facial Coverings"].reset_index(drop=True)[0]

ip = create_ip(selected_country, c1, c2, c3, c4, c5, c6, c7, c8, h1, h2, h3, h6, n_days)
		pred = predict(ip)
		df = data[data["CountryName"]==selected_country].reset_index(drop=True)
		df = df[["CountryName", "Date", "ConfirmedCases", "ConfirmedDeaths", "DailyNewCases", "DailyNewDeaths"]]
		t = pred.copy()
		t = t[["CountryName", "Date", "PredictedDailyTotalCases", "PredictedDailyTotalDeaths", "PredictedDailyNewCases", "PredictedDailyNewDeaths"]]
		t.rename(columns={"PredictedDailyTotalCases":"ConfirmedCases",
			"PredictedDailyTotalDeaths":"ConfirmedDeaths",
			"PredictedDailyNewCases":"DailyNewCases",
			"PredictedDailyNewDeaths":"DailyNewDeaths"}, inplace=True)
		t = t.round()
		dfn = pd.concat([df, t])
		dfn = dfn.tail(90+n_days).reset_index(drop=True) #dfn[334:].reset_index(drop=True)
		dfn["DailyNewCasesMA"] = dfn["DailyNewCases"].rolling(7).mean()
		dfn["DailyNewCasesMA"].fillna(dfn["DailyNewCases"], inplace=True)
		dfn["DailyNewCases"] = dfn["DailyNewCasesMA"]

		dfn.to_csv("src/data/cached_30/cached_30_{}.csv".format(selected_country), index=False)
		st.write("Saved ", selected_country,"!")
